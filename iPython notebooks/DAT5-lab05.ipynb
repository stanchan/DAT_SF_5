# %% [markdown]
# # GA Data Science 5 (DAT5) - Lab5
#
# ### Regressions
#
# Francesco Mosconi
# Chief Data Officer, [Spire Inc.](spire.io)

# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#usual imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Statsmodel APIs
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Load a subset of the housing data

# %%
data = pd.read_csv('data/houses.csv')

# %%
data.head()
# Out:
#    sqft  bedrooms  age   price
# 0  2104         3   70  399900
# 1  1600         3   28  329900
# 2  2400         3   44  369000
# 3  1416         2   49  232000
# 4  3000         4   75  539900
#
# [5 rows x 4 columns]

# %%
data_n = pd.read_csv('data/houses_norm.csv')

# %% [markdown]
# The dataset contains 4 columns. Our objective is to build a model that is able to predict the price of a house, using the information contained in the other columns (sqft, bedrooms and age)

# %%
from pandas.tools.plotting import scatter_matrix
scat = scatter_matrix(data, figsize= (6,6))

# %% [markdown]
# Run 1. x = sqft, data is raw (so graph units are nice right)

# %% [markdown]
# Let''s start with a simple model that uses the house surface to estimate the price

# %%
x = data['sqft'].values
y = data['price'].values

# %%
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     122.3
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.03e-14
# Time:                        20:40:04   Log-Likelihood:                -586.94
# No. Observations:                  47   AIC:                             1178.
# Df Residuals:                      45   BIC:                             1182.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       7.127e+04   2.61e+04      2.725      0.009      1.86e+04  1.24e+05
# x1           134.5253     12.165     11.058      0.000       110.024   159.027
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.726
# Skew:                           0.557   Prob(JB):                        0.256
# Kurtosis:                       3.390   Cond. No.                     5.88e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 5.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Run 2:  x = sqft, data is normalized (so summary stats are nice)

# %%
data_n.head()
# Out:
#     sqft  bedrooms  age  price
# 0  2.104         3  7.0  3.999
# 1  1.600         3  2.8  3.299
# 2  2.400         3  4.4  3.690
# 3  1.416         2  4.9  2.320
# 4  3.000         4  7.5  5.399
#
# [5 rows x 4 columns]

# %%
x = data_n['sqft'].values
y = data_n['price'].values
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params
r2 = results.rsquared
plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     122.3
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.03e-14
# Time:                        20:41:35   Log-Likelihood:                -45.831
# No. Observations:                  47   AIC:                             95.66
# Df Residuals:                      45   BIC:                             99.36
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.7127      0.261      2.725      0.009         0.186     1.239
# x1             1.3453      0.122     11.058      0.000         1.100     1.590
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.726
# Skew:                           0.557   Prob(JB):                        0.256
# Kurtosis:                       3.390   Cond. No.                         7.01
# ==============================================================================
# """

# %% [markdown]
# Confidence Intervals

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std

prstd, iv_l, iv_u = wls_prediction_std(results)

# %%
fig, ax = plt.subplots(figsize=(6,6))

#ax.plot(x, y, 'o', label="data")
#ax.plot(x, results.fittedvalues, 'r-', label="OLS")
#ax.plot(x, iv_u, 'r-')
#ax.plot(x, iv_l, 'r-')
#ax.legend(loc='best')

ax.plot([x, y, 'o', label="data"],
        [x, results.fittedvalues, 'r-', label="OLS"],
        [x, iv_u, 'r-'],
        [x, iv_l, 'r-'])
ax.legend(loc='best')
# Out:
#   File "<ipython-input-92-34f10378a217>", line 9
#     ax.plot([x, y, 'o', label="data"],
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Function of Bedrooms?

# %% [markdown]
# Run 3:  x = bdrms, data is raw (so graph units are nice)

# %%
x = data['bedrooms'].values
y = data['price'].values
# Out:
# <function matplotlib.pyplot.show>

# %%
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params
r2 = results.rsquared
plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.title(r2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):            0.00185
# Time:                        20:51:31   Log-Likelihood:                -612.68
# No. Observations:                  47   AIC:                             1229.
# Df Residuals:                      45   BIC:                             1233.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         1.1e+05   7.16e+04      1.537      0.131     -3.41e+04  2.54e+05
# x1          7.267e+04    2.2e+04      3.308      0.002      2.84e+04  1.17e+05
# ==============================================================================
# Omnibus:                        4.709   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.412
# Skew:                           0.691   Prob(JB):                        0.110
# Kurtosis:                       2.413   Cond. No.                         15.4
# ==============================================================================
# """

# %% [markdown]
# ## Function of Age?

# %%
x = data['age'].values
y = data['price'].values

# %%
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params
r2 = results.rsquared
plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.title(r2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                    0.1210
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):              0.730
# Time:                        20:52:38   Log-Likelihood:                -617.73
# No. Observations:                  47   AIC:                             1239.
# Df Residuals:                      45   BIC:                             1243.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       3.283e+05   3.94e+04      8.341      0.000      2.49e+05  4.08e+05
# x1           283.1207    813.819      0.348      0.730     -1355.994  1922.236
# ==============================================================================
# Omnibus:                        8.665   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.374
# Skew:                           1.025   Prob(JB):                       0.0152
# Kurtosis:                       3.270   Cond. No.                         103.
# ==============================================================================
# """

# %%
x = data_n['age'].values
y = data_n['price'].values

# %%
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
intercept, slope = results.params
r2 = results.rsquared
plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.title(r2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                    0.1210
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):              0.730
# Time:                        20:52:41   Log-Likelihood:                -76.624
# No. Observations:                  47   AIC:                             157.2
# Df Residuals:                      45   BIC:                             160.9
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          3.2831      0.394      8.341      0.000         2.490     4.076
# x1             0.0283      0.081      0.348      0.730        -0.136     0.192
# ==============================================================================
# Omnibus:                        8.665   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.374
# Skew:                           1.025   Prob(JB):                       0.0152
# Kurtosis:                       3.270   Cond. No.                         10.7
# ==============================================================================
# """

# %% [markdown]
# ## Function of multiple variables

# %%
x = data_n[['sqft', 'bedrooms', 'age']].values
y = data_n['price'].values

X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     39.38
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.12e-12
# Time:                        20:54:16   Log-Likelihood:                -45.641
# No. Observations:                  47   AIC:                             99.28
# Df Residuals:                      43   BIC:                             106.7
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.9245      0.449      2.060      0.045         0.019     1.830
# x1             1.3933      0.150      9.305      0.000         1.091     1.695
# x2            -0.0862      0.156     -0.551      0.584        -0.402     0.229
# x3            -0.0081      0.043     -0.188      0.852        -0.095     0.079
# ==============================================================================
# Omnibus:                        3.841   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                2.771
# Skew:                           0.552   Prob(JB):                        0.250
# Kurtosis:                       3.444   Cond. No.                         28.9
# ==============================================================================
# """

# %% [markdown]
# ## 3D Plot

# %%
# 3d plot
from mpl_toolkits.mplot3d import Axes3D

x = data[['sqft', 'bedrooms','age']].values
y = data['price'].values

fignum = 1
fig = plt.figure(fignum, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=38, azim=124)

plt.cla()
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()

# est.fit(X)
# ax.scatter(X[:, 0], X[:, 1], X[:, 3], c=labels.astype(np.float))
ax.scatter(X[:, 1], X[:, 0], X[:, 3])

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_ylabel('Sqft')
ax.set_xlabel('Bedrooms')
ax.set_zlabel('Price')
plt.show()

# %% [markdown]
# ## Just sqft & bedrooms

# %%
x = data_n[['sqft', 'bedrooms']].values
y = data_n['price'].values
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     60.38
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.43e-13
# Time:                        21:03:26   Log-Likelihood:                -45.660
# No. Observations:                  47   AIC:                             97.32
# Df Residuals:                      44   BIC:                             102.9
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.8960      0.418      2.145      0.037         0.054     1.738
# x1             1.3921      0.148      9.409      0.000         1.094     1.690
# x2            -0.0874      0.155     -0.566      0.575        -0.399     0.224
# ==============================================================================
# Omnibus:                        4.083   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.977
# Skew:                           0.567   Prob(JB):                        0.226
# Kurtosis:                       3.484   Cond. No.                         18.0
# ==============================================================================
# """

# %%
x
# Out:
# array([[ 2.104,  3.   ],
#        [ 1.6  ,  3.   ],
#        [ 2.4  ,  3.   ],
#        [ 1.416,  2.   ],
#        [ 3.   ,  4.   ],
#        [ 1.985,  4.   ],
#        [ 1.534,  3.   ],
#        [ 1.427,  3.   ],
#        [ 1.38 ,  3.   ],
#        [ 1.494,  3.   ],
#        [ 1.94 ,  4.   ],
#        [ 2.   ,  3.   ],
#        [ 1.89 ,  3.   ],
#        [ 4.478,  5.   ],
#        [ 1.268,  3.   ],
#        [ 2.3  ,  4.   ],
#        [ 1.32 ,  2.   ],
#        [ 1.236,  3.   ],
#        [ 2.609,  4.   ],
#        [ 3.031,  4.   ],
#        [ 1.767,  3.   ],
#        [ 1.888,  2.   ],
#        [ 1.604,  3.   ],
#        [ 1.962,  4.   ],
#        [ 3.89 ,  3.   ],
#        [ 1.1  ,  3.   ],
#        [ 1.458,  3.   ],
#        [ 2.526,  3.   ],
#        [ 2.2  ,  3.   ],
#        [ 2.637,  3.   ],
#        [ 1.839,  2.   ],
#        [ 1.   ,  1.   ],
#        [ 2.04 ,  4.   ],
#        [ 3.137,  3.   ],
#        [ 1.811,  4.   ],
#        [ 1.437,  3.   ],
#        [ 1.239,  3.   ],
#        [ 2.132,  4.   ],
#        [ 4.215,  4.   ],
#        [ 2.162,  4.   ],
#        [ 1.664,  2.   ],
#        [ 2.238,  3.   ],
#        [ 2.567,  4.   ],
#        [ 1.2  ,  3.   ],
#        [ 0.852,  2.   ],
#        [ 1.852,  4.   ],
#        [ 1.203,  3.   ]])

# %% [markdown]
# ## The formula API

# %%
results = smf.ols('price - sqft + bedrooms', data=data).fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-105-2cab20bfc3b7> in <module>()
# ----> 1 results = smf.ols('price - sqft + bedrooms', data=data).fit()
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#      96         if subset is not None:
#      97             data= data.ix[subset]
# ---> 98         endog, exog = handle_formula_data(data, None, formula)
#      99         mod = cls(endog, exog, *args, **kwargs)
#     100         mod.formula = formula
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth)
#      43     else:
#      44         if data_util._is_using_pandas(Y, None):
# ---> 45             return dmatrices(formula, Y, 2, return_type='dataframe')
#      46         else:
#      47             return dmatrices(formula, Y, 2, return_type='dataframe')
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
# --> 299         raise PatsyError("model is missing required outcome variables")
#     300     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %% [markdown]
# ## Nonlinear Fitting

# %% [markdown]
# Let's generate points with an arbitrary nonlinear function

# %% [markdown]
# $y = \frac{1}{2} x + \frac{1}{2} \sin{x} - \frac{1}{50} (x-2)^2 + 5$

# %%
# start with some fate date
nsample = 50
sig = 0.5
# generate linear space
x = np.linspace(0, 20, nsample)
# invent function
X = np.c_[x, np.sin(x), (x-5)**2, np.ones(nsample)]
# invent cofficients                         
beta = [0.5, 0.5, -0.02, 5.]
#generate
y_true = np.dot(X, beta)
# add noise
y = y_true + sig * np.random.normal(size=nsample)

# %% [markdown]
# quick look at the data

# %%
# nice
plot(x, y_true)
scatter(x, y, c='g')
show()

# %%
res = sm.OLS(y, X).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     233.9
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           7.50e-28
# Time:                        21:10:40   Log-Likelihood:                -33.622
# No. Observations:                  50   AIC:                             75.24
# Df Residuals:                      46   BIC:                             82.89
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.5049      0.026     19.435      0.000         0.453     0.557
# x2             0.4669      0.102      4.572      0.000         0.261     0.672
# x3            -0.0204      0.002     -8.956      0.000        -0.025    -0.016
# const          5.0691      0.168     30.094      0.000         4.730     5.408
# ==============================================================================
# Omnibus:                        1.886   Durbin-Watson:                   2.557
# Prob(Omnibus):                  0.389   Jarque-Bera (JB):                1.226
# Skew:                          -0.011   Prob(JB):                        0.542
# Kurtosis:                       2.233   Cond. No.                         221.
# ==============================================================================
# """

# %% [markdown]
# I can access the results attributes

# %% [markdown]
# Let's look at the fit!

# %%
plt.figure*

# %% [markdown]
# ## Overfitting

# %%
x = np.array([-0.99768, -0.69574, -0.40373, -0.10236, 0.22024, 0.47742, 0.82229])
y = np.array([2.0885, 1.1646, 0.3287, 0.46013, 0.44808, 0.10013, -0.32952])

# %% [markdown]
# ### Linear fit

# %% [markdown]
# ### Quadratic

# %%
X = np.c_[x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-824c19695993> in <module>()
#       1 X = np.c_[x**2, x, np.ones(len(x))]
# ----> 2 res = sm.OLS(y, X).fit()
#
# NameError: name 'sm' is not defined

# %% [markdown]
# ### Quintic

# %%
X = np.c_[x**5, x**4, x**3, x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge = Ridge()
ridge.fit(np.vander(x, 6), y)

lasso = Lasso(alpha = 0.1)
lasso.fit(np.vander(x, 6), y)

plt.figure(figsize = (6,6))
plt.plot(x, y, 'o')
xx = np.linspace(-1.25,1.1,100)
plt.plot(xx, res.predict(np.vander(xx, 6)), 'r-')
plt.plot(xx, ridge.predict(np.vander(xx, 6)), 'g-', label='Ridge')
plt.plot(xx, ridge.predict(np.vander(xx, 6)), 'c-', label='Lasso')
plt.legend(loc='best')
